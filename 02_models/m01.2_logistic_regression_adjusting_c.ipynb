# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.float_format='{:.2f}'.format
plt.style.use('seaborn')
import sklearn as skl
from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import io
import shutil
import warnings
warnings.filterwarnings("ignore")

# %%
fpth='mushroom_data_clean.csv'
df=pd.read_csv(fpth)
# df=df.replace("'",'',regex=True)
# columns=list(df.columns)
# columns=[x.replace("'","") for x in columns]
# df.columns=columns
df.head()
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           s         n       t    p               f            c
# 1         x           s         y       t    a               f            c
# 2         b           s         w       t    l               f            c
# 3         x           y         w       t    p               f            c
# 4         x           s         g       f    n               f            w
#
#   gill-size gill-color stalk-shape  ... stalk-color-above stalk-color-below  \
# 0         n          k           e  ...                 w                 w
# 1         b          k           e  ...                 w                 w
# 2         b          n           e  ...                 w                 w
# 3         n          n           e  ...                 w                 w
# 4         b          k           t  ...                 w                 w
#
# ...

# %%
df.describe()
# Out:
#        cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count       8124        8124      8124    8124  8124            8124
# unique         6           4        10       2     9               2
# top            x           y         n       f     n               f
# freq        3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color stalk-shape  ... stalk-color-above  \
# count          8124      8124       8124        8124  ...              8124
# unique            2         2         12           2  ...                 9
# top               c         b          b           t  ...                 w
# freq           6812      5612       1728        4608  ...              4464
#
#        stalk-color-below veil-type veil-color ring-number ring-type  \
# count               8124      8124       8124        8124      8124
# unique                 9         1          4           3         5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   cap-shape            8124 non-null   object
#  1   cap-surface          8124 non-null   object
#  2   cap-color            8124 non-null   object
#  3   bruises              8124 non-null   object
#  4   odor                 8124 non-null   object
#  5   gill-attachment      8124 non-null   object
#  6   gill-spacing         8124 non-null   object
#  7   gill-size            8124 non-null   object
#  8   gill-color           8124 non-null   object
#  9   stalk-shape          8124 non-null   object
#  10  stalk-root           8124 non-null   object
#  11  stalk-surface-above  8124 non-null   object
#  12  stalk-surface-below  8124 non-null   object
#  13  stalk-color-above    8124 non-null   object
#  14  stalk-color-below    8124 non-null   object
# ...

# %%
for c in df.columns:
    print(c,df[c].unique())
# Out:
# cap-shape ['x' 'b' 's' 'f' 'k' 'c']
# cap-surface ['s' 'y' 'f' 'g']
# cap-color ['n' 'y' 'w' 'g' 'e' 'p' 'b' 'u' 'c' 'r']
# bruises ['t' 'f']
# odor ['p' 'a' 'l' 'n' 'f' 'c' 'y' 's' 'm']
# gill-attachment ['f' 'a']
# gill-spacing ['c' 'w']
# gill-size ['n' 'b']
# gill-color ['k' 'n' 'g' 'p' 'w' 'h' 'u' 'e' 'b' 'r' 'y' 'o']
# stalk-shape ['e' 't']
# stalk-root ['e' 'c' 'b' 'r' '?']
# stalk-surface-above ['s' 'f' 'k' 'y']
# stalk-surface-below ['s' 'f' 'y' 'k']
# stalk-color-above ['w' 'g' 'p' 'n' 'b' 'e' 'o' 'c' 'y']
# stalk-color-below ['w' 'p' 'g' 'b' 'n' 'e' 'y' 'o' 'c']
# veil-type ['p']
# veil-color ['w' 'n' 'o' 'y']
# ring-number ['o' 't' 'n']
# ring-type ['p' 'e' 'l' 'f' 'n']
# spore-print-color ['k' 'n' 'u' 'h' 'w' 'r' 'o' 'y' 'b']
# population ['s' 'n' 'a' 'v' 'y' 'c']
# habitat ['u' 'g' 'm' 'd' 'p' 'w' 'l']
# class ['p' 'e']

# %%
df.drop(columns=['stalk-root'],inplace=True)
df.head()
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           s         n       t    p               f            c
# 1         x           s         y       t    a               f            c
# 2         b           s         w       t    l               f            c
# 3         x           y         w       t    p               f            c
# 4         x           s         g       f    n               f            w
#
#   gill-size gill-color stalk-shape  ... stalk-color-above stalk-color-below  \
# 0         n          k           e  ...                 w                 w
# 1         b          k           e  ...                 w                 w
# 2         b          n           e  ...                 w                 w
# 3         n          n           e  ...                 w                 w
# 4         b          k           t  ...                 w                 w
#
# ...

# %%
df.columns
# Out:
# Index(['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-surface-above', 'stalk-surface-below',
#        'stalk-color-above', 'stalk-color-below', 'veil-type', 'veil-color',
#        'ring-number', 'ring-type', 'spore-print-color', 'population',
#        'habitat', 'class'],
#       dtype='object')

# %%
ordinal_encoders={}
for col in  df.columns:
    enc=preprocessing.OrdinalEncoder()
    ordinal_encoders[col]=enc
    df[col]=enc.fit_transform(df[[col]])

# %%
y=df['class']
df.drop(columns=['class'],inplace=True)
X=df

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=1,stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',random_state=1)
classifier
# Out:
# LogisticRegression(random_state=1)

# %%
C= np.linspace(0.01, 1000.0,num=5)
print(C)
scores = []
for choice in C:
    classifier.set_params(C=choice)
    classifier.fit(X, y)
    to_save=(c,classifier.score(X_train, y_train),classifier.score(X_test, y_test))
    scores+=[to_save]
print(scores)
#conclusion:  adjusting the c value of the logistic regression classifier is a not beneficial
# Out:
# [1.000000e-02 2.500075e+02 5.000050e+02 7.500025e+02 1.000000e+03]
# [('class', 0.9094042343673068, 0.9049729197439685), ('class', 0.9451829968816675, 0.9423929098966026), ('class', 0.9432135237157394, 0.9414081733136386), ('class', 0.9443623830625307, 0.9423929098966026), ('class', 0.9438700147710487, 0.9419005416051206)]

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.9438700147710487
# Testing Data Score: 0.9419005416051206

# %%
predictions = classifier.predict(X_test)
pd.DataFrame({"Prediction": predictions, "Actual": y_test})
# Out:
#       Prediction  Actual
# 5525        0.00    0.00
# 5868        1.00    1.00
# 5111        1.00    1.00
# 3193        1.00    1.00
# 1561        0.00    0.00
# ...          ...     ...
# 5822        1.00    1.00
# 2781        0.00    0.00
# 6980        1.00    1.00
# 4207        1.00    1.00
# 2914        0.00    0.00
#
# [2031 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, predictions)
# Out:
# 0.9443623830625307

# %%
for col in df.columns:
    enc=ordinal_encoders[col]
    df[col]=enc.inverse_transform(df[[col]])
df.head()
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           s         n       t    p               f            c
# 1         x           s         y       t    a               f            c
# 2         b           s         w       t    l               f            c
# 3         x           y         w       t    p               f            c
# 4         x           s         g       f    n               f            w
#
#   gill-size gill-color stalk-shape  ... stalk-surface-below stalk-color-above  \
# 0         n          k           e  ...                   s                 w
# 1         b          k           e  ...                   s                 w
# 2         b          n           e  ...                   s                 w
# 3         n          n           e  ...                   s                 w
# 4         b          k           t  ...                   s                 w
#
# ...
