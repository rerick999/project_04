# %% [markdown]
# I had to first run:
# pip install mysql-connector-python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# %%
csv_file = "../02_models/mushroom_data_clean.csv"
mushroom_df = pd.read_csv(csv_file)

mushroom_df.head()
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           s         n       t    p               f            c
# 1         x           s         y       t    a               f            c
# 2         b           s         w       t    l               f            c
# 3         x           y         w       t    p               f            c
# 4         x           s         g       f    n               f            w
#
#   gill-size gill-color stalk-shape  ... stalk-color-above stalk-color-below  \
# 0         n          k           e  ...                 w                 w
# 1         b          k           e  ...                 w                 w
# 2         b          n           e  ...                 w                 w
# 3         n          n           e  ...                 w                 w
# 4         b          k           t  ...                 w                 w
#
# ...

# %%
# creating dictionaries to replace string values with integers

cap_shape = {'b': 0, 'c': 1, 'f': 2, 'k': 3, 's': 4, 'x': 5}
cap_surface = {'f': 0, 'g': 1, 's': 2, 'y': 3}
cap_color = {'b': 0, 'c': 1, 'e': 2, 'g': 3, 'n': 4, 'p': 5, 'r': 6, 'u': 7, 'w': 8, 'y': 9}
bruises = {'f': 0, 't': 1}
odor = {'a': 0, 'c': 1, 'f': 2, 'l': 3, 'm': 4, 'n': 5, 'p': 6, 's': 7, 'y': 8}
gill_attach = {'a': 0, 'd': 1, 'f': 2, 'n': 3}
gill_space = {'c': 0, 'd': 1, 'w': 2}
gill_size = {'b': 0, 'n': 1}
gill_color = {'b': 0, 'e': 1, 'g': 2, 'h': 3, 'k': 4, 'n': 5, 'o': 6, 'p': 7, 'r': 8, 'u': 9, 'w': 10, 'y': 11}
stalk_shape = {'e': 0, 't': 1}
stalk_root = {'b': 0, 'c': 1, 'e': 2, 'r': 3, 'u': 4, 'z': 5}
stalk_surf_above = {'f': 0, 'k': 1, 's': 2, 'y': 3}
stalk_surf_below = {'f': 0, 'k': 1, 's': 2, 'y': 3}
stalk_color_above = {'b': 0, 'c': 1, 'e': 2, 'g': 3, 'n': 4, 'o': 5, 'p': 6, 'w': 7, 'y': 8}
stalk_color_below = {'b': 0, 'c': 1, 'e': 2, 'g': 3, 'n': 4, 'o': 5, 'p': 6, 'w': 7, 'y': 8}
veil_type = {'p': 0, 'u': 1}
veil_color = {'n': 0, 'o': 1, 'w': 2, 'y': 3}
ring_number = {'n': 0, 'o': 1, 't': 2}
ring_type = {'c': 0, 'e': 1, 'f': 2, 'l': 3, 'n': 4, 'p': 5, 's': 6, 'z': 7}
spore_color = {'b': 0, 'h': 1, 'k': 2, 'n': 3, 'o': 4, 'r': 5, 'u': 6, 'w': 7, 'y': 8}
population = {'a': 0, 'c': 1, 'n': 2, 's': 3, 'v': 4, 'y': 5}
habitat = {'d': 0, 'g': 1, 'l': 2, 'm': 3, 'p': 4, 'u': 5, 'w': 6}
poisonous = {"e": 0, "p": 1}

# %% [markdown]
# cap-shape
# cap-surface,
# cap-color,
# bruises,
# odor,
# gill-attachment,
# gill-spacing,
# gill-size,
# gill-color,
# stalk-shape,
# stalk-root,
# stalk-surface-above,
# stalk-surface-below,
# stalk-color-above,
# stalk-color-below,
# veil-type,
# veil-color,
# ring-number,
# ring-type,
# spore-print-color,
# population,
# habitat,
# class

# %%
mushroom_df["cap-shape"].replace(cap_shape, inplace=True)
mushroom_df["cap-surface"].replace(cap_surface, inplace=True)
mushroom_df["cap-color"].replace(cap_color, inplace=True)
mushroom_df["bruises"].replace(bruises, inplace=True)
mushroom_df["odor"].replace(odor, inplace=True)
mushroom_df["gill-attachment"].replace(gill_attach, inplace=True)
mushroom_df["gill-spacing"].replace(gill_space, inplace=True)
mushroom_df["gill-size"].replace(gill_size, inplace=True)
mushroom_df["gill-color"].replace(gill_color, inplace=True)
mushroom_df["stalk-shape"].replace(stalk_shape, inplace=True)
mushroom_df["stalk-root"].replace(stalk_root, inplace=True)
mushroom_df["stalk-surface-below"].replace(stalk_surf_below, inplace=True)
mushroom_df["stalk-surface-above"].replace(stalk_surf_above, inplace=True)
mushroom_df["stalk-color-above"].replace(stalk_color_above, inplace=True)
mushroom_df["stalk-color-below"].replace(stalk_color_below, inplace=True)
mushroom_df["veil-type"].replace(veil_type, inplace=True)
mushroom_df["veil-color"].replace(veil_color, inplace=True)
mushroom_df["ring-number"].replace(ring_number, inplace=True)
mushroom_df["ring-type"].replace(ring_type, inplace=True)
mushroom_df["spore-print-color"].replace(spore_color, inplace=True)
mushroom_df["population"].replace(population, inplace=True)
mushroom_df["habitat"].replace(habitat, inplace=True)
mushroom_df["class"].replace(poisonous, inplace=True)

mushroom_df.head()
# Out:
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0          5            2          4        1     6                2
# 1          5            2          9        1     0                2
# 2          0            2          8        1     3                2
# 3          5            3          8        1     6                2
# 4          5            2          3        0     5                2
#
#    gill-spacing  gill-size  gill-color  stalk-shape  ... stalk-color-above  \
# 0             0          1           4            0  ...                 7
# 1             0          0           4            0  ...                 7
# 2             0          0           5            0  ...                 7
# 3             0          1           5            0  ...                 7
# 4             2          0           4            1  ...                 7
#
#    stalk-color-below  veil-type  veil-color  ring-number  ring-type  \
# ...

# %%
X = mushroom_df.drop(columns=["class", "stalk-root"])
y = mushroom_df["class"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
xgb = XGBClassifier()

# %%
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7]
}

# %%
grid_search = GridSearchCV(xgb, param_grid, cv=5)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_bin=None,
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
# ...

# %%
best_xgb = grid_search.best_estimator_

# %%
feature_importances = best_xgb.feature_importances_

feature_names = X_train.columns
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)
print(importance_df)
# Out:
#                 Feature  Importance
# 8            gill-color    0.554716
# 19           population    0.091092
# 4                  odor    0.087273
# 18    spore-print-color    0.062144
# 12    stalk-color-above    0.056822
# 7             gill-size    0.055316
# 11  stalk-surface-below    0.017989
# 10  stalk-surface-above    0.012630
# 6          gill-spacing    0.011527
# 2             cap-color    0.008140
# 13    stalk-color-below    0.008132
# 16          ring-number    0.007174
# 9           stalk-shape    0.006666
# 20              habitat    0.006085
# 15           veil-color    0.005063
# 17            ring-type    0.003035
# 3               bruises    0.002872
# 0             cap-shape    0.002649
# 1           cap-surface    0.000676
# 14            veil-type    0.000000
# 5       gill-attachment    0.000000

# %%
y_pred = best_xgb.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print(f"Best Estimators: {best_xgb.n_estimators}")
print(f"Best Learning Rate: {best_xgb.learning_rate}")
print(f"Best Max Depth: {best_xgb.max_depth}")
print(f"Accuracy: {accuracy:.2f}")
print(f"F1: {f1:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
# Out:
# Best Estimators: 200
# Best Learning Rate: 0.1
# Best Max Depth: 3
# Accuracy: 1.00
# F1: 1.00
# Precision: 1.00
# Recall: 1.00
